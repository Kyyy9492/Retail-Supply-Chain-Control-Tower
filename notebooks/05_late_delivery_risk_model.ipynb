# %% [markdown]
# # 05 - Late Delivery Risk Model
#
# This notebook is part of the Retail Supply Chain Control Tower project.

# %% [markdown]
# ## Objective
# Predict whether an order is likely to be delivered late.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score

# %% [markdown]
# ## Modeling Table
# Use SQL output from `model_late_delivery_features`.

# %%
# TODO: Load modeling CSV exported from MySQL and train baseline logistic regression.
