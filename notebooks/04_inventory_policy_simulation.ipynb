# %% [markdown]
# # 04 - Inventory Policy Simulation
#
# This notebook is part of the Retail Supply Chain Control Tower project.

# %% [markdown]
# ## Objective
# Compare baseline vs. forecast-based reorder-point policies.

# %%
import pandas as pd
import numpy as np
from src.inventory_policy import safety_stock, reorder_point, simulate_inventory_policy

# %% [markdown]
# ## Policy Assumptions
# Document lead time, service level, holding cost, and stockout penalty.

# %%
# TODO: Calculate reorder point and simulate inventory outcomes.
