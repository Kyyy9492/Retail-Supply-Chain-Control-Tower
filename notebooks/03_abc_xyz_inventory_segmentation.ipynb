# %% [markdown]
# # 03 - ABC/XYZ Inventory Segmentation
#
# This notebook is part of the Retail Supply Chain Control Tower project.

# %% [markdown]
# ## Objective
# Classify SKUs by value contribution and demand variability.

# %%
import pandas as pd
import numpy as np
from src.inventory_policy import assign_abc, assign_xyz

# %% [markdown]
# ## ABC Analysis
# Classify SKUs by cumulative revenue or demand value.

# %%
# TODO: Create SKU-level value table and run assign_abc().

# %% [markdown]
# ## XYZ Analysis
# Classify SKUs by coefficient of variation.

# %%
# TODO: Create SKU-level demand mean/std table and run assign_xyz().
