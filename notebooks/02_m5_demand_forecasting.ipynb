# %% [markdown]
# # 02 - M5 Demand Forecasting
#
# This notebook is part of the Retail Supply Chain Control Tower project.

# %% [markdown]
# ## Objective
# Build a demand forecasting workflow for SKU-store daily sales.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from src.metrics import mae, rmse, wape
from src.forecasting import moving_average_forecast

# %% [markdown]
# ## Load M5 Data
# Place M5 files under `data/raw/m5/`.

# %%
# sales = pd.read_csv("../data/raw/m5/sales_train_evaluation.csv")
# calendar = pd.read_csv("../data/raw/m5/calendar.csv")
# prices = pd.read_csv("../data/raw/m5/sell_prices.csv")

# %% [markdown]
# ## Model Plan
# 1. Moving average baseline
# 2. Exponential smoothing or SARIMA
# 3. Optional ML model with lag features

# %%
# TODO: Select top SKU-store combinations and compare forecast metrics.
