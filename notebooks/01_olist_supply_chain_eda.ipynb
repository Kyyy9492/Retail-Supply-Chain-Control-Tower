# %% [markdown]
# # 01 - Olist Supply Chain EDA
#
# This notebook is part of the Retail Supply Chain Control Tower project.

# %% [markdown]
# ## Objective
# Analyze delivery performance, freight cost, seller reliability, and review outcomes.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

DATA_DIR = Path("../data/raw/olist")
OUTPUT_DIR = Path("../outputs")

# %% [markdown]
# ## Load Data
# Place Olist CSV files under `data/raw/olist/` before running this notebook.

# %%
# Example after downloading raw files:
# orders = pd.read_csv(DATA_DIR / "olist_orders_dataset.csv", parse_dates=[
#     "order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date",
#     "order_delivered_customer_date", "order_estimated_delivery_date"
# ])

# %% [markdown]
# ## KPI Ideas
# - Total orders
# - Late delivery rate
# - Average delivery days
# - Freight-to-price ratio
# - Review score by delivery status

# %%
# TODO: Build order-level KPI table after loading raw data.
